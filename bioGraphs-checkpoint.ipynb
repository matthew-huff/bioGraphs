# %%
import matplotlib.pyplot as plt

# %%
time = [0, .5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]

# %%
results1 = [.012, .012, .012, .012, .012, .012, .011, .011, .011, .011, .011]
results2 = [.003, .003, .003, .003, .003, .003, .003, .003, .003, .003, .003]
results3 = [.005, .005, .005, .005, .005, .005, .005, .005, .005, .005, .005]
results4 = [.022, .021, .022, .023, .023, .023, .023, .024, .024, .023, .024]

# %%
results5 = [.407, .691, .782, .879, .925, .962, 1.013, 1.027, .996, .931, .898]
results6 = [.137, .485, .654, .740, .776, .789, .790, .786, .781, .774, .767]
results7 = [.762, 1.086, 1.272, 1.392, 1.465, 1.513, 1.540, 1.555, 1.564, 1.568, 1.569]
results8 = [.628, 1, 1.190, 1.294, 1.344, 1.370, 1.379, 1.381, 1.379, 1.376, 1.373]
results9 = [.872, 1.448, 1.785, 2.004, 2.143, 2.242, 2.311, 2.352, 2.380, 2.402, 2.415]

# %%
plt.axis([0, 5, 0, 2.6])
# Out:
# [0, 5, 0, 2.6]

# %% [markdown]
# # Cells for results 5 through results 9.

# %%
plt.plot(time, results5, 'b-', label="4.7 mL water, 0.1mL Gluaiacol, 0.2 mL Hydrogen Peroxide, 1.0 mL Turnip Extract")
plt.plot(time, results6, 'r-', label="4.2 mL water, 0.1mL Gluaiacol, 0.2 mL Hydrogen Peroxide, 1.0 mL Turnip Extract, .5 mL Hydroxylamine")
plt.plot(time, results7, 'g-', label="3.7 mL water, 0.1mL Gluaiacol, 0.2 mL Hydrogen Peroxide, 1.5 mL Turnip Extract, .5 mL Hydroxylamine")
plt.plot(time, results8, 'c-', label="3.2 mL water, 0.1mL Gluaiacol, 0.2 mL Hydrogen Peroxide, 2.0 mL Turnip Extract, .5 mL Hydroxylamine")
plt.plot(time, results9, 'm-', label="2.2 mL water, 0.1mL Gluaiacol, 0.2 mL Hydrogen Peroxide, 3.0 mL Turnip Extract, .5 mL Hydroxylamine")
plt.xlabel("Time (in minutes)")
plt.ylabel("Spectrophotometer\n Absorbance at 470nm")
plt.title("Results\nExperiments 5-9")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig = plt.gcf()
fig.set_size_inches(12.5, 6)
fig.savefig('5through9.png', dpi=100)
plt.show()

# %% [markdown]
# # Cells for results 1 through 4

# %%
plt.axis([0, 5, 0, .032])
plt.plot(time, results1, 'm-', time, results2, 'b-', time, results3, 'r-', time, results4, 'g-')
plt.plot(time, results1, 'm-', label="5.9mL water, 0.1mL Gluaiacol")
plt.plot(time, results2, 'b-', label="5.8mL water, 0.2mL Hydrogen Peroxide")
plt.plot(time, results3, 'r-', label="5.7mL water, 0.1mL Gluaiacol, 0.2mL Hydrogen Peroxide")
plt.plot(time, results4, 'g-', label="4.9mL water, 0.1mL Gluaiacol, 1.0 mL Turnip Extract")
plt.xlabel("Time (in minutes)")
plt.ylabel("Spectrophotometer\n Absorbance at 470nm")
plt.title("Results\nExperiments 1-4")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig = plt.gcf()
fig.set_size_inches(12.5, 6)
fig.savefig('1through4.png', dpi=100)
plt.show()
